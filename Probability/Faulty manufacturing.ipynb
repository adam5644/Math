# %% [markdown]
# A manufacturing puts tires on 2 cars (4 tires each). Each tire has 10% probability of being flat. If manufacturer puts tires onto first car, then second car. Whats the probability that at least 1 car has no working tires?
# ![image.png](attachment:image.png)
