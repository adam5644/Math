# %% [raw]
# (q)
# x ~ exp(1)
# y/x ~ lognorm(0,k)
# find cov(x,y)
#
# (a)
# r ~ lognorm(mu, sigma**2) if log(r) ~ n(mu, sigma**2)
# cov(x,y) = E[XY] - E[X]E[Y]
# E[Y] = E[E[Y|X]]
#
# E[yx] = exp(mu + 0.5 sigma**2) = exp(0.5k)
# mgf of exponential dist x is M(theta) = 1/(1-theta)

# %% [markdown]
# ![image.png](attachment:image.png)
